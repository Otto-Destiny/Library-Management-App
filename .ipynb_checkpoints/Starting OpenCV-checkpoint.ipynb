# %%
import cv2
import os
os.listdir()
import numpy as np

# %%
mmg = cv2.imread('WhatsApp Image 2020-10-04 at 6.58.19 AM.jpeg', 1)
mmg
# Out:
# array([[[191, 221, 238],
#         [191, 221, 238],
#         [191, 221, 238],
#         ...,
#         [147, 158, 185],
#         [147, 158, 185],
#         [147, 158, 185]],
#
#        [[191, 221, 238],
#         [191, 221, 238],
#         [191, 221, 238],
#         ...,
#         [147, 158, 185],
#         [147, 158, 185],
#         [147, 158, 185]],
#
#        [[191, 221, 238],
#         [191, 221, 238],
#         [191, 221, 238],
#         ...,
#         [147, 158, 185],
#         [147, 158, 185],
#         [147, 158, 185]],
#
#        ...,
#
#        [[ 75,  46,  49],
#         [ 75,  46,  49],
#         [ 75,  46,  49],
#         ...,
#         [202, 105,  55],
#         [203, 106,  56],
#         [205, 108,  58]],
#
#        [[ 75,  46,  49],
#         [ 75,  46,  49],
#         [ 75,  46,  49],
#         ...,
#         [202, 105,  55],
#         [203, 106,  56],
#         [205, 108,  58]],
#
#        [[ 75,  46,  49],
#         [ 75,  46,  49],
#         [ 75,  46,  49],
# ...

# %%
type(mmg)
# Out:
# numpy.ndarray

# %%
np.shape(mmg)
# Out:
# (716, 720, 3)

# %%
mmg.shape
# Out:
# (716, 720, 3)

# %%
hy = numpy.vsplit(mmg, 4)
hy
# Out:
# [array([[[191, 221, 238],
#          [191, 221, 238],
#          [191, 221, 238],
#          ...,
#          [147, 158, 185],
#          [147, 158, 185],
#          [147, 158, 185]],
#
#         [[191, 221, 238],
#          [191, 221, 238],
#          [191, 221, 238],
#          ...,
#          [147, 158, 185],
#          [147, 158, 185],
#          [147, 158, 185]],
#
#         [[191, 221, 238],
#          [191, 221, 238],
#          [191, 221, 238],
#          ...,
#          [147, 158, 185],
#          [147, 158, 185],
#          [147, 158, 185]],
#
#         ...,
#
#         [[ 45,  59,  78],
#          [ 45,  60,  79],
#          [ 45,  60,  79],
#          ...,
#          [163, 174, 201],
#          [163, 174, 201],
#          [164, 175, 202]],
#
#         [[ 47,  59,  77],
#          [ 48,  60,  78],
#          [ 48,  60,  78],
#          ...,
#          [158, 175, 201],
#          [158, 175, 201],
#          [159, 176, 202]],
#
#         [[ 47,  59,  77],
# ...

# %%
type(hy)
# Out:
# list
